# %% [markdown]
# Code and data from the article "Black hole information turbulence and the Hubble tension"
# Copyright (C) 2025  Juan Luis Cabrera Fernández
#
# This project is licensed under the terms of the Attribution-NonCommercial-ShareAlike 4.0 International - Creative Commons licence (CC BY-NC-SA 4.0).
#  https://creativecommons.org/licenses/by-nc-sa/4.0/deed.en
#
# This code builds Figure 3, Figure 8 and Figure 9
#
# Loads figXsoloY1.jl
# with X: HLCDM, EDE or EDEP
# loads figHLCDMsoloY1.jl , figEDEsoloY1.jl and figEDEPsoloY1.jl

# %%
# Adding julia packages
import Pkg; 

Pkg.add("Plots")
Pkg.add("DelimitedFiles")
Pkg.add("LaTeXStrings")
Pkg.add("DataFrames")
Pkg.add("Latexify")
Pkg.add("JLD")
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.11/Project.toml`
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`

# %%
using LaTeXStrings
using CSV, DataFrames, Plots, DelimitedFiles
using Plots, Plots.PlotMeasures
include("./figHLCDMsoloY1-rev1-v1.jl")
#posteriorMcg,  posteriorMmotif = 
figHLCDM()
# Out:
# Dimension : Dcg
# Now the IdDD SERIES RUNS FROM x=2
#
# Posterior Parameters and their errors:
#  ph 116.11166254507977 eph 20.20806660922336 pe 1.5394577465059274 epe 0.029837881123684313
# y must be D with no sqrt (!)
# The error in the extrapolation is estimated as the mean of errY in the large fluctuation domain, i.e, errY[1:4]
# Dcd : h_0 = 62.78992088168562 ± 4.557899297442076
# Now the IdDDmotifs SERIES RUNS FROM x=2
# 25
#
# Posterior Parameters and their errors:
#  ph 74.00340654896453 eph 5.47544625203358e-7 pe 1.4090493643341993 epe 2.171700097922551e-5
# y must be D with no sqrt (!)
# Dmotif : h_0 = 70.06506401227269 ± 0.3903090679116587
# El elemento 26 a tau=1 : 70.06506401227269
# GOING OUT ...

# %%
#sqrt.(posteriorMcg)
#scatter(sqrt.(posteriorMcg))

# %%
pwd()
# Out:
# "/Users/jlc/EnElaboracion/Population_LeonardSusskind/paper_darkMatter/SciRep/Respuesta1/code"

# %%
#include("/home/jlc/EnElaboracion/Cascading_ReservoirNN/prog/Susskind/figEDE1.jl")
#include("/home/jlc/EnElaboracion/Cascading_ReservoirNN/prog/Susskind/figEDE1Y2corrected.jl")
include("./figEDEsoloY1-rev1-v1.jl")

figEDE()
# Out:
# Dimension : Dcg
# Now the IdDD SERIES RUNS FROM x=2
# Esquema : Y1
#
# Posterior Parameters and their errors:
#  ph 127.86789894732317 eph 2.8688959015091 pe 1.4957261028272504 epe 0.0034682839777022832
# y must be D with no sqrt (!)
# The error in the extrapolation is estimated as the mean of errY in the large fluctuation domain, i.e, errY[1:4]
# Dcd : h_0 = 78.90700554248022 ± 0.8626589637458294
# Now the IdDDmotifs SERIES RUNS FROM x=2
# 25
# Esquema : Y1
#
# Posterior Parameters and their errors:
#  ph 35.684637338498 eph 1.2330487157586116 pe 1.4981829575098327 epe 0.004934372741994072
# 37.568606328337275
# y must be D with no sqrt (!)
# Dmotif : h_0 = 37.568606328337275 ± 0.645057193982469
# El elemento 26 a tau=1 : 37.568606328337275
# GOING OUT ...

# %%
using LaTeXStrings
using CSV, DataFrames, Plots, DelimitedFiles
using Plots, Plots.PlotMeasures
include("./figEDEPsoloY1-rev1-v1.jl")

figEDEP()
# Out:
# Dimension : Dcg
# Now the IdDD SERIES RUNS FROM x=2
# Esquema : Y1
#
# Posterior Parameters and their errors:
#  ph 134.60357920832996 eph 9.984620134457638 pe 1.5167852244158981 epe 0.014345274995317054
# y must be D with no sqrt (!)
# The error in the extrapolation is estimated as the mean of errY in the large fluctuation domain, i.e, errY[1:4]
# Dcd : h_0 = 73.54982366721015 ± 2.4089671771962653
# Now the IdDDmotifs SERIES RUNS FROM x=2
# 25
# Esquema : Y1
#
# Posterior Parameters and their errors:
#  ph 39.81151192502147 eph 1.078104154376815 pe 1.511521371138682 epe 0.0033313777886436317
# 36.910269934085974
# y must be D with no sqrt (!)
# Dmotif : h_0 = 36.910269934085974 ± 0.5865393516314796
# El elemento 26 a tau=1 : 36.910269934085974
# GOING OUT ...

# %%
# COMENTO ESTO. ESTA VERSION VIENE DEL MSI JACINTA. HAY QUE TRAER Main-fig3-HLCDM1.jl DE ALLA SI SE TRATA DE HACER LA DEFINITIVA
#using LaTeXStrings
#using CSV, DataFrames, Plots, DelimitedFiles
#using Plots, Plots.PlotMeasures
# Not provided: the same as above
#include("./Main-fig3-HLCDM1.jl")
#MainfigHLCDM()

# %%
using LaTeXStrings
using CSV, DataFrames, Plots, DelimitedFiles
using Plots, Plots.PlotMeasures
#include("./figHLCDMsoloY1.jl")
include("./figHLCDM_instability-rev1-v2.jl")
figHLCDM_instability()
# Out:
# Dimension : Dcg
# Now the IdDD SERIES RUNS FROM x=2
# Esquema : Y1
# 0.015926122950278745
# Esquema : Y1
# 70.06506401227269
# 62.967554011898294
# 68.09802987928977
# H_0 : 62.96755401189831
#  h0n : 62.96755401189831
# H_0 : 68.09802987928978
#  h0n : 68.09802987928978
# SALIENDO
